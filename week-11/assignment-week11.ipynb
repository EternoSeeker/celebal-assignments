# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
# Load the image
img = cv2.imread('rose.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Convert to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Plot original image
plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')

# Plot grayscale image
plt.subplot(222)
plt.imshow(img_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
# Out:
# (-0.5, 3007.5, 1999.5, -0.5)

# %%
# Plot pixel value distribution for grayscale image
plt.subplot(223)
plt.hist(img_gray.ravel(), bins=256, range=(0, 256), density=True)
plt.title('Pixel Value Distribution (Grayscale)')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Calculate and plot RGB histograms
colors = ('r', 'g', 'b')
plt.subplot(224)
for i, color in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color=color)
    plt.xlim([0, 256])
plt.title('RGB Histograms')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Additional analysis: Color distribution in 3D space
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

r, g, b = cv2.split(img)
ax.scatter(r.ravel(), g.ravel(), b.ravel(), c=img_rgb.reshape(-1, 3)/255.0, s=1)
ax.set_xlabel('Red')
ax.set_ylabel('Green')
ax.set_zlabel('Blue')
ax.set_title('3D Color Distribution')

plt.show()

# %%
# Calculate and print some statistics
for i, color in enumerate(['Red', 'Green', 'Blue']):
    channel = img[:,:,i]
    print(f"{color} channel:")
    print(f"  Mean: {np.mean(channel):.2f}")
    print(f"  Std Dev: {np.std(channel):.2f}")
    print(f"  Min: {np.min(channel)}")
    print(f"  Max: {np.max(channel)}")
    print()
# Out:
# Red channel:
#   Mean: 38.28
#   Std Dev: 40.14
#   Min: 0
#   Max: 255
#
# Green channel:
#   Mean: 51.31
#   Std Dev: 38.09
#   Min: 0
#   Max: 255
#
# Blue channel:
#   Mean: 81.62
#   Std Dev: 77.65
#   Min: 0
#   Max: 255
